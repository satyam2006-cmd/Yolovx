# %%
print("Hello, World!")

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="dgHo0LlAYM7nxKIrclIf")
project = rf.workspace("satyam-bhagat-s-workspace").project("vehicle-queue-detection-sf2st")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 89.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 141.3 MB/s eta 0:00:0000:01
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.13
#     Uninstalling idna-3.13:
#       Successfully uninstalled idna-3.13
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Vehicle-queue-detection-1 in yolov8:: 100%|██████████| 6143/6143 [00:00<00:00, 7689.11it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.4 MB/s eta 0:00:0000:01
# ...

# %%
import os
print(os.listdir("/content"))
print(os.listdir("/content/Vehicle queue detection.v1i.yolov8"))

# %% [markdown]
# # Training

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/Vehicle queue detection.v1i.yolov8/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# ...
# C:\Users\satya\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\__init__.py:109: RequestsDependencyWarning: urllib3 (1.26.20) or chardet (6.0.0.post1)/charset_normalizer (3.4.1) doesn't match a supported version!
#   warnings.warn(
# Ultralytics 8.4.47  Python-3.13.7 torch-2.11.0+cpu CPU (12th Gen Intel Core i5-12450H)
# ...

# %% [markdown]
# # Prediction

# %%
model.predict(
    source="/content/Vehicle queue detection.v1i.yolov8/test/images",
    save=True
)
