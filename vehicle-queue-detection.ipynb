# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="dgHo0LlAYM7nxKIrclIf")
project = rf.workspace("satyam-bhagat-s-workspace").project("vehicle-queue-detection-sf2st")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 39.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 69.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 106.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.4 MB/s eta 0:00:00
# ...

# %%
import os
print(os.listdir("/kaggle/working/"))
print(os.listdir("/kaggle/working/Vehicle-queue-detection-1"))
# Out:
# ['Vehicle-queue-detection-1', '__notebook__.ipynb']
# ['README.roboflow.txt', 'test', 'train', 'README.dataset.txt', 'data.yaml', 'valid']

# %% [markdown]
# # Training

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/kaggle/working/Vehicle-queue-detection-1/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.47 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# # Prediction

# %%
model.predict(
    source="/kaggle/working/Vehicle-queue-detection-1/test/images",
    save=True
)
# Out:
# image 1/128 /kaggle/working/Vehicle-queue-detection-1/test/images/103_jpg.rf.a9a5aebcbd824d9160fc6f81735e3098.jpg: 640x640 15 vehicles, 6.0ms
# image 2/128 /kaggle/working/Vehicle-queue-detection-1/test/images/117_jpg.rf.f76f3de4a2b87774e46665e37254aec0.jpg: 640x640 14 vehicles, 5.9ms
# image 3/128 /kaggle/working/Vehicle-queue-detection-1/test/images/121_jpg.rf.5ac374951753958bee11665933c9ef9b.jpg: 640x640 13 vehicles, 5.7ms
# image 4/128 /kaggle/working/Vehicle-queue-detection-1/test/images/122_jpg.rf.9a001f85dbfcec921fa0584f6b40e54e.jpg: 640x640 15 vehicles, 5.7ms
# image 5/128 /kaggle/working/Vehicle-queue-detection-1/test/images/1256_jpg.rf.cf84587216e6dd808a2e22ea28342fbd.jpg: 640x640 12 vehicles, 5.9ms
# image 6/128 /kaggle/working/Vehicle-queue-detection-1/test/images/142_jpg.rf.92b4f376e2a4077528b2c3c437d6eef9.jpg: 640x640 17 vehicles, 6.1ms
# ...

# %%
from ultralytics import YOLO

model = YOLO("/kaggle/working/runs/detect/train/weights/best.pt")

results = model("https://www.wagnerreese.com/content/uploads/2023/04/Highways.jpg", save=True)
# Out:
# WARNING ⚠️ Download failure, retrying 1/3 https://www.wagnerreese.com/content/uploads/2023/04/Highways.jpg... HTTP Error 403: Forbidden
# ##O#-#
# image 1/1 /kaggle/working/Highways.jpg: 448x640 23 vehicles, 41.2ms
# Speed: 2.0ms preprocess, 41.2ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /kaggle/working/runs/detect/predict-2
# ######################################################################## 100.0%

# %%
from ultralytics import YOLO

model = YOLO("/kaggle/working/runs/detect/train/weights/last.pt")

results = model("https://upload.wikimedia.org/wikipedia/commons/2/25/Mumbai_03-2016_109_Western_Express_Highway_near_Bandra.jpg", save=True)
# Out:
# WARNING ⚠️ Download failure, retrying 1/3 https://upload.wikimedia.org/wikipedia/commons/2/25/Mumbai_03-2016_109_Western_Express_Highway_near_Bandra.jpg... HTTP Error 403: Forbidden
# ######################################################################## 100.0%
# image 1/1 /kaggle/working/Mumbai_03-2016_109_Western_Express_Highway_near_Bandra.jpg: 416x640 16 vehicles, 40.8ms
# Speed: 2.9ms preprocess, 40.8ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to /kaggle/working/runs/detect/predict-3
